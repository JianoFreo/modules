# %% [markdown]
# # Dynamic Programming Assessment - 20 Problems
#
# Master DP: 1D, 2D, knapsack, LCS, LIS, memoization, tabulation
#
# ---
#
# ## EASY (DP1-DP5)

# %% [markdown]
# <span style="color:green">**DP1: Fibonacci Sequence**</span>
# Compute fib(5) with memoization.
#
# **Output:** `5` (0,1,1,2,3,5)

# %%
# DP1 Solution

# %% [markdown]
# <span style="color:green">**DP2: Climbing Stairs**</span>
# Ways to climb n=3 stairs (1 or 2 steps).
#
# **Output:** `3` (1+1+1, 1+2, 2+1)

# %%
# DP2 Solution

# %% [markdown]
# <span style="color:green">**DP3: House Robber**</span>
# Max loot. nums=[1,2,3,1].
#
# **Output:** `4` (rob 1st and 3rd)

# %%
# DP3 Solution

# %% [markdown]
# <span style="color:green">**DP4: Min Cost Climbing Stairs**</span>
# Min cost to reach top. cost=[10,15,20].
#
# **Output:** `15` (start from index 1)

# %%
# DP4 Solution

# %% [markdown]
# <span style="color:green">**DP5: Best Time To Buy Sell Stock**</span>
# Max profit. prices=[7,1,5,3,6,4].
#
# **Output:** `5` (buy 1, sell 6)

# %%
# DP5 Solution

# %% [markdown]
# ---
#
# ## INTERMEDIATE (DP6-DP12)

# %% [markdown]
# <span style="color:green">**DP6: Longest Common Subsequence**</span>
# LCS of "abcde" and "ace".
#
# **Output:** `3` ("ace")

# %%
# DP6 Solution

# %% [markdown]
# <span style="color:green">**DP7: Longest Increasing Subsequence**</span>
# LIS of [10,9,2,5,3,7,101,18].
#
# **Output:** `4` ([2,3,7,101])

# %%
# DP7 Solution

# %% [markdown]
# <span style="color:green">**DP8: 0/1 Knapsack**</span>
# Max value. weights=[2,3,4], values=[3,4,5], capacity=5.
#
# **Output:** `9` (items 1,2)

# %%
# DP8 Solution

# %% [markdown]
# <span style="color:green">**DP9: Coin Change**</span>
# Min coins. coins=[1,2,5], amount=5.
#
# **Output:** `1` (one coin 5)

# %%
# DP9 Solution

# %% [markdown]
# <span style="color:green">**DP10: Partition Equal Subset Sum**</span>
# Can partition [1,5,11,5].
#
# **Output:** `True` ([5,5,11])

# %%
# DP10 Solution

# %% [markdown]
# <span style="color:green">**DP11: Edit Distance**</span>
# Min edits from "horse" to "ros".
#
# **Output:** `3`

# %%
# DP11 Solution

# %% [markdown]
# <span style="color:green">**DP12: Maximum Product Subarray**</span>
# Max product of contiguous. [2,3,-2,4].
#
# **Output:** `6` ([2,3])

# %%
# DP12 Solution

# %% [markdown]
# ---
#
# ## ADVANCED (DP13-DP17)

# %% [markdown]
# <span style="color:green">**DP13: Minimum Window Substring**</span>
# Use DP for min substring. s="ADOBECODEBANC", t="ABC".
#
# **Output:** `"BANC"`

# %%
# DP13 Solution

# %% [markdown]
# <span style="color:green">**DP14: Regular Expression Matching**</span>
# Match with . and *. s="aa", p="a" -> False. s="aa", p="a*" -> True.
#
# **Output:** `True/False` based on pattern

# %%
# DP14 Solution

# %% [markdown]
# <span style="color:green">**DP15: Burst Balloons**</span>
# Max coins. nums=[3,1,5,8].
#
# **Output:** `167` (optimal burst order)

# %%
# DP15 Solution

# %% [markdown]
# <span style="color:green">**DP16: Maximal Rectangle**</span>
# Max rectangle with 1s. matrix=[["1","0","1"],["1","0","1"],["1","1","1"]].
#
# **Output:** `6` (area)

# %%
# DP16 Solution

# %% [markdown]
# <span style="color:green">**DP17: Distinct Subsequences**</span>
# Count distinct subsequences. s="rabbbit", t="rabbit".
#
# **Output:** `3`

# %%
# DP17 Solution

# %% [markdown]
# ---
#
# ## EXPERT (DP18-DP20)

# %% [markdown]
# <span style="color:green">**DP18: Number of Ways to Make Change**</span>
# Ways to make amount. coins=[1,2,5], amount=5.
#
# **Output:** `4` (1+1+1+1+1, 1+1+1+2, 1+2+2, 5)

# %%
# DP18 Solution

# %% [markdown]
# <span style="color:green">**DP19: Range Sum Query Immutable**</span>
# Efficient range queries. nums=[3,0,-2,6], sumRange(0,2) = 1.
#
# **Output:** Query results

# %%
# DP19 Solution

# %% [markdown]
# <span style="color:green">**DP20: Triangle Min Path Sum**</span>
# Min path. triangle=[[2],[3,4],[6,5,7],[4,1,8,3]].
#
# **Output:** `11` (2+3+5+1)

# %%
# DP20 Solution

# %% [markdown]
# ---
#
# ## Summary
# DP mastery: 1D patterns → 2D grids → string matching → advanced optimizations
