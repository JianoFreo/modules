# %% [markdown]
# # 08_Sorting - Complete DSA Guide
#
# ## 📚 Lesson Section
#
# ### Sorting Algorithms
#
# | Algorithm | Best | Avg | Worst | Space | Stable |
# |-----------|------|-----|-------|-------|--------|
# | Bubble | O(n) | O(n²) | O(n²) | O(1) | Yes |
# | Selection | O(n²) | O(n²) | O(n²) | O(1) | No |
# | Insertion | O(n) | O(n²) | O(n²) | O(1) | Yes |
# | Merge | O(n log n) | O(n log n) | O(n log n) | O(n) | Yes |
# | Quick | O(n log n) | O(n log n) | O(n²) | O(log n) | No |
# | Heap | O(n log n) | O(n log n) | O(n log n) | O(1) | No |
# | Bucket | O(n+k) | O(n+k) | O(n²) | O(n+k) | Yes |

# %%
# Python's built-in sort (Timsort - O(n log n))
arr = [64, 34, 25, 12, 22, 11]
arr.sort()  # In-place
print(f"Sorted: {arr}")

# Using sorted() - returns new list
original = [3, 1, 4, 1, 5, 9]
sorted_arr = sorted(original)
print(f"Original: {original}")
print(f"Sorted: {sorted_arr}")

# Custom sorting
strs = ["apple", "pie", "a", "bat"]
sorted_by_len = sorted(strs, key=len)
print(f"By length: {sorted_by_len}")

# %% [markdown]
# ### Key Sorting Patterns
#
# #### 1. **Bubble Sort**

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

# %% [markdown]
# #### 2. **Quick Sort**

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

# %% [markdown]
# ### 🔑 Key Points Before Assessment
#
# ✅ **Remember:**
# 1. Use python's `sort()` for interviews (O(n log n))
# 2. Know when to use stable vs unstable
# 3. Space-time tradeoff: merge O(n log n) but O(n) space
#
# ---
