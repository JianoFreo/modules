# %% [markdown]
# # 13_Graphs - Complete DSA Guide
#
# ## 📚 Lesson Section
#
# ### What is a Graph?
# A **graph** is a collection of nodes (vertices) connected by edges.
#
# ```
# Undirected:      Directed:
#   1 -- 2           1 → 2
#   |    |           ↓    ↓
#   3 -- 4           3 → 4
# ```
#
# **Key Properties:**
# - DFS: O(V + E) for connected components
# - BFS: O(V + E) for shortest path (unweighted)
# - Topological sort: directed acyclic graph
# - Cycle detection important

# %% [markdown]
# ### 🔑 Key Points Before Assessment
#
# ✅ **Remember:**
# 1. DFS for cycles and components
# 2. BFS for shortest path
# 3. Topological sort for DAG
# 4. Adjacency list for sparse graphs
# 5. Adjacency matrix for dense graphs
#
# ---

# %% [markdown]
# ## 🎯 LeetCode-Style Problems
#
# ### Problem 1: Number of Islands
# **Difficulty:** Medium | **Time Limit:** 15 min
#
# Count connected components (islands) in grid.
#
# **Example:**
# ```
# Input: grid = [[1,1,0],[1,0,0]]
# Output: 1
# ```

# %%
grid = [[1,1,0],[1,0,0]]
print(numIslands(grid))  # Expected: 1

# %% [markdown]
# ### Problem 2: Clone Graph
# **Difficulty:** Medium | **Time Limit:** 15 min
#
# Deep copy an undirected graph.
#
# **Example:**
# ```
# Input: graph = [[2,4],[1,3],[2,4],[1,3]]
# Output: [[2,4],[1,3],[2,4],[1,3]]
# ```

# %%
print("Clone graph test")

# %% [markdown]
# ### Problem 3: Topological Sort
# **Difficulty:** Medium | **Time Limit:** 15 min
#
# Sort nodes by dependency order (DAG).
#
# **Example:**
# ```
# Input: numCourses=4, edges=[[1,0],[2,0],[3,1],[3,2]]
# Output: [0,1,2,3] or [0,2,1,3]
# ```

# %%
print(topologicalSort(4, [[1,0],[2,0],[3,1],[3,2]]))  # Expected: valid topological order

# %% [markdown]
# ### Problem 4: Alien Dictionary
# **Difficulty:** Hard | **Time Limit:** 20 min
#
# Determine order of alien alphabet from word list.
#
# **Example:**
# ```
# Input: ["wrt","wrf","er","ett","rftt"]
# Output: "wertf"
# ```

# %%
print(alienOrder(["wrt","wrf","er","ett","rftt"]))  # Expected: "wertf"

# %% [markdown]
# ### Problem 5: Course Schedule
# **Difficulty:** Medium | **Time Limit:** 10 min
#
# Determine if courses can be completed (no cycles).
#
# **Example:**
# ```
# Input: numCourses=2, edges=[[1,0]]
# Output: True
#
# Input: numCourses=2, edges=[[1,0],[0,1]]
# Output: False (cycle)
# ```

# %%
print(canFinish(2, [[1,0]]))          # Expected: True
print(canFinish(2, [[1,0],[0,1]]))  # Expected: False
