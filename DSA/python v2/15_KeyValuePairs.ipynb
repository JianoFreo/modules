# %% [markdown]
# # 15_KeyValuePairs - Complete DSA Guide
#
# ## 📚 Lesson Section
#
# ### What are Key-Value Pairs?
# **Key-value pairs** store associations between keys and values for fast lookup.
#
# ```
# Dictionary: {"name": "Alice", "age": 25, "city": "NYC"}
# Key → Value mapping
# ```
#
# **Key Properties:**
# - O(1) average lookup
# - Unique keys
# - Useful for mappings, frequencies, caching
# - Can be ordered or unordered

# %% [markdown]
# ### 🔑 Key Points Before Assessment
#
# ✅ **Remember:**
# 1. Unique keys requirement
# 2. O(1) lookup on average
# 3. Use for frequency/mapping problems
# 4. defaultdict for default values
# 5. Check key existence before access
#
# ---

# %% [markdown]
# ## 🎯 LeetCode-Style Problems
#
# ### Problem 1: Word Pattern
# **Difficulty:** Easy | **Time Limit:** 5 min
#
# Check if pattern matches word sequence (one-to-one mapping).
#
# **Example:**
# ```
# Input: pattern="abba", words=["dog","cat","cat","dog"]
# Output: True
# ```

# %%
print(wordPattern("abba", ["dog","cat","cat","dog"]))  # Expected: True
print(wordPattern("abba", ["dog","cat","cat","fish"]))  # Expected: False

# %% [markdown]
# ### Problem 2: Valid Sudoku
# **Difficulty:** Medium | **Time Limit:** 10 min
#
# Check if 9x9 sudoku board is valid.
#
# **Example:**
# ```
# 3x3 blocks, rows, and columns must have 1-9 without repetition
# ```

# %%
board = [['5','3','.','.','7','.','.','.','.'],
         ['6','.','.','1','9','5','.','.','.']
]
print(isValidSudoku(board))  # Expected: True (partial check)

# %% [markdown]
# ### Problem 3: Happy Number
# **Difficulty:** Easy | **Time Limit:** 5 min
#
# Check if number reaches 1 by sum of squares.
#
# **Example:**
# ```
# Input: 7
# Output: True
# ```

# %%
print(isHappy(19))  # Expected: True
print(isHappy(2))   # Expected: False

# %% [markdown]
# ### Problem 4: Contains Duplicate II
# **Difficulty:** Easy | **Time Limit:** 5 min
#
# Check if duplicate exists within distance k.
#
# **Example:**
# ```
# Input: nums=[99,99], k=2
# Output: True
# ```

# %%
print(containsNearbyDuplicate([99,99], 2))  # Expected: True
print(containsNearbyDuplicate([99,99], 1))  # Expected: False

# %% [markdown]
# ### Problem 5: Word Ladder
# **Difficulty:** Hard | **Time Limit:** 20 min
#
# Find shortest transformation path.
#
# **Example:**
# ```
# Input: beginWord="hit", endWord="cog", wordList=["hot","dot","dog","lot","log","cog"]
# Output: 5 (hit→hot→dot→dog→cog)
# ```

# %%
print(ladderLength("hit", "cog", ["hot","dot","dog","lot","log","cog"]))  # Expected: 5
