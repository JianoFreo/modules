# %% [markdown]
# # Greedy Assessment - 20 Problems
#
# Master greedy algorithms: interval scheduling, activity selection, optimization
#
# ---
#
# ## EASY (GR1-GR5)

# %% [markdown]
# <span style="color:green">**GR1: Assign Cookies**</span>
# Maximize satisfied children. g=[1,2,3], s=[1,1].
#
# **Output:** `1` (one child satisfied)

# %%
# GR1 Solution

# %% [markdown]
# <span style="color:green">**GR2: Jump Game**</span>
# Can reach last index. [2,3,1,1,4].
#
# **Output:** `True`

# %%
# GR2 Solution

# %% [markdown]
# <span style="color:green">**GR3: Majority Element**</span>
# Find element > n/2 times. [3,2,3].
#
# **Output:** `3`

# %%
# GR3 Solution

# %% [markdown]
# <span style="color:green">**GR4: Lemonade Change**</span>
# Calculate change with bills. bills=[5,5,10,20,5,5,5,5,5,5,5,5,5,10,5,5,20,5,20,5].
#
# **Output:** `False` (cannot always give change)

# %%
# GR4 Solution

# %% [markdown]
# <span style="color:green">**GR5: Minimize Absolute Difference**</span>
# Rearrange to minimize sum of absolute diff. a=[3,5,10], b=[2,4,3].
#
# **Output:** `Minimum difference

# %%
# GR5 Solution

# %% [markdown]
# ---
#
# ## INTERMEDIATE (GR6-GR12)

# %% [markdown]
# <span style="color:green">**GR6: Interval Scheduling**</span>
# Max non-overlapping intervals. [[1,2],[2,3],[3,4],[1,3]].
#
# **Output:** `3` (max intervals)

# %%
# GR6 Solution

# %% [markdown]
# <span style="color:green">**GR7: Erasing After Writing**</span>
# Minimum erasers. s="ababab", e=2.
#
# **Output:** `1`

# %%
# GR7 Solution

# %% [markdown]
# <span style="color:green">**GR8: Gas Station**</span>
# Can complete circuit. gas=[1,2,3,4,5], cost=[3,4,5,1,2].
#
# **Output:** `3` (start from index 3)

# %%
# GR8 Solution

# %% [markdown]
# <span style="color:green">**GR9: Two City Scheduling**</span>
# Min cost to send people. costs=[[10,20],[30,200],[50,50],[200,30]].
#
# **Output:** `110`

# %%
# GR9 Solution

# %% [markdown]
# <span style="color:green">**GR10: Best Time To Buy Sell Stock II**</span>
# Max profit unlimited transactions. [7,1,5,3,6,4].
#
# **Output:** `5` (buy 1, sell 5, buy 3, sell 6)

# %%
# GR10 Solution

# %% [markdown]
# <span style="color:green">**GR11: Jump Game II**</span>
# Min jumps to reach end. [2,3,1,1,4].
#
# **Output:** `2`

# %%
# GR11 Solution

# %% [markdown]
# <span style="color:green">**GR12: Reconstruct Itinerary**</span>
# Valid itinerary from tickets. [["MUC","LHR"],["JFK","MUC"],["SFO","SJC"],["LHR","SFO"]].
#
# **Output:** `["JFK","MUC","LHR","SFO","SJC"]`

# %%
# GR12 Solution

# %% [markdown]
# ---
#
# ## ADVANCED (GR13-GR17)

# %% [markdown]
# <span style="color:green">**GR13: Meeting Rooms**</span>
# Can attend all meetings. [[0,30],[5,10],[15,20]].
#
# **Output:** `False` (overlap at [5,10] with [0,30])

# %%
# GR13 Solution

# %% [markdown]
# <span style="color:green">**GR14: Coin Change**</span>
# Min coins for amount. coins=[1,2,5], amount=5.
#
# **Output:** `1` (one coin of 5)

# %%
# GR14 Solution

# %% [markdown]
# <span style="color:green">**GR15: Maximum Subarray**</span>
# Max sum contiguous. [-2,1,-3,4,-1,2,1,-5,4].
#
# **Output:** `6` ([4,-1,2,1])

# %%
# GR15 Solution

# %% [markdown]
# <span style="color:green">**GR16: Minimum Deletions**</span>
# Min deletions to make valid. s="loonbalxballpoon".
#
# **Output:** `2`

# %%
# GR16 Solution

# %% [markdown]
# <span style="color:green">**GR17: Dota2 Senate**</span>
# Optimal voting strategy. senate="RRDR".
#
# **Output:** `"Dire"` (winning faction)

# %%
# GR17 Solution

# %% [markdown]
# ---
#
# ## EXPERT (GR18-GR20)

# %% [markdown]
# <span style="color:green">**GR18: Patching Array**</span>
# Min patches to reach target. nums=[1,5,10], n=20.
#
# **Output:** `2` (patch array)

# %%
# GR18 Solution

# %% [markdown]
# <span style="color:green">**GR19: Video Stitching**</span>
# Min videos to reach target. clips=[[0,2],[4,6],[8,10],[1,9],[1,5],[5,9]], T=10.
#
# **Output:** `3`

# %%
# GR19 Solution

# %% [markdown]
# <span style="color:green">**GR20: Maximum Score From Array**</span>
# Max score following rules. nums=[3,4,6,2,5], k=2.
#
# **Output:** Maximum score achieved

# %%
# GR20 Solution

# %% [markdown]
# ---
#
# ## Summary
# Greedy mastery: activity selection → interval scheduling → optimization problems
