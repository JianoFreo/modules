# %% [markdown]
# # Key-Value Pairs Assessment - 20 Problems
#
# Master dictionaries: creation, access, iteration, nesting, grouping, caching
#
# ---
#
# ## EASY (KV1-KV5)

# %% [markdown]
# <span style="color:green">**KV1: Create and Access Dictionary**</span>
# Create dict with keys 'name', 'age', 'city' and access 'name'.
#
# **Output:** `'John'`

# %%
# KV1 Solution

# %% [markdown]
# <span style="color:green">**KV2: Add and Update Values**</span>
# Add 'email' key and update 'age' to 26. Original: {'name': 'John', 'age': 25}.
#
# **Output:** `{'name': 'John', 'age': 26, 'email': 'john@example.com'}`

# %%
# KV2 Solution

# %% [markdown]
# <span style="color:green">**KV3: Keys, Values, Items**</span>
# Extract keys, values, items from {'a': 1, 'b': 2, 'c': 3}.
#
# **Output:** `['a', 'b', 'c']`, `[1, 2, 3]`, `[('a', 1), ('b', 2), ('c', 3)]`

# %%
# KV3 Solution

# %% [markdown]
# <span style="color:green">**KV4: Get with Default**</span>
# Get value or default. dict={'name': 'John'}, get 'email' with default 'N/A'.
#
# **Output:** `'N/A'`

# %%
# KV4 Solution

# %% [markdown]
# <span style="color:green">**KV5: Delete Keys**</span>
# Delete 'age' from {'name': 'John', 'age': 25, 'city': 'NYC'}.
#
# **Output:** `{'name': 'John', 'city': 'NYC'}`

# %%
# KV5 Solution

# %% [markdown]
# ---
#
# ## INTERMEDIATE (KV6-KV12)

# %% [markdown]
# <span style="color:green">**KV6: Count Frequency**</span>
# Count character frequency in 'aabbcc'.
#
# **Output:** `{'a': 2, 'b': 2, 'c': 2}`

# %%
# KV6 Solution

# %% [markdown]
# <span style="color:green">**KV7: Group by Key**</span>
# Group [{'type': 'A', 'val': 1}, {'type': 'B', 'val': 2}, {'type': 'A', 'val': 3}] by 'type'.
#
# **Output:** `{'A': [1, 3], 'B': [2]}`

# %%
# KV7 Solution

# %% [markdown]
# <span style="color:green">**KV8: Sort by Value**</span>
# Sort {'b': 2, 'a': 3, 'c': 1} by value descending.
#
# **Output:** `[('a', 3), ('b', 2), ('c', 1)]`

# %%
# KV8 Solution

# %% [markdown]
# <span style="color:green">**KV9: Nested Dictionary**</span>
# Create and access nested: {'user': {'name': 'John', 'address': {'city': 'NYC'}}}.
#
# **Output:** `'NYC'`

# %%
# KV9 Solution

# %% [markdown]
# <span style="color:green">**KV10: Merge Dictionaries**</span>
# Merge {'a': 1, 'b': 2} and {'c': 3, 'd': 4}.
#
# **Output:** `{'a': 1, 'b': 2, 'c': 3, 'd': 4}`

# %%
# KV10 Solution

# %% [markdown]
# <span style="color:green">**KV11: defaultdict Usage**</span>
# Use defaultdict to count words in ['apple', 'banana', 'apple'].
#
# **Output:** `defaultdict(<class 'int'>, {'apple': 2, 'banana': 1})`

# %%
# KV11 Solution

# %% [markdown]
# <span style="color:green">**KV12: Counter Class**</span>
# Use Counter for 'aabbcc'.
#
# **Output:** `Counter({'a': 2, 'b': 2, 'c': 2})`

# %%
# KV12 Solution

# %% [markdown]
# ---
#
# ## ADVANCED (KV13-KV17)

# %% [markdown]
# <span style="color:green">**KV13: Anagram Grouping**</span>
# Group anagrams from ['eat', 'tea', 'ate', 'dog', 'god'].
#
# **Output:** `{'eat': ['eat', 'tea', 'ate'], 'dog': ['dog', 'god']}`

# %%
# KV13 Solution

# %% [markdown]
# <span style="color:green">**KV14: Two Sum with HashMap**</span>
# Find indices [3, 1, 4, 1, 5], target=9.
#
# **Output:** `[0, 4]` (indices of 4 and 5)

# %%
# KV14 Solution

# %% [markdown]
# <span style="color:green">**KV15: Word Pattern Matching**</span>
# Validate pattern 'abba' against 'dog dog cat cat'.
#
# **Output:** `True`

# %%
# KV15 Solution

# %% [markdown]
# <span style="color:green">**KV16: First Unique Element**</span>
# Find first non-repeating in 'loveleetcode'.
#
# **Output:** `'v'`

# %%
# KV16 Solution

# %%
# KV17 Solution

# %%
# KV20 Solution

# %% [markdown]
# ---
#
# ## Summary
# Key-Value Pairs mastery: basic ops → frequency counting → grouping → advanced caching
