# %% [markdown]
# # Linked List Assessment - 20 Problems
#
# Master linked lists from basic to expert level!
#
# ---
#
# ## EASY (Problems 1-5)

# %% [markdown]
# <span style="color:green">**L1: Create a Node Class**</span>
# Create a simple Node class with data and next pointer.
#
# **Expected Output:**
# ```
# Node created with data=5
# ```

# %%
# L1 Solution

# %% [markdown]
# <span style="color:green">**L2: Create LinkedList Class**</span>
# Create a LinkedList class with head pointer and basic structure.
#
# **Expected Output:**
# ```
# LinkedList created with head=None
# ```

# %%
# L2 Solution

# %% [markdown]
# <span style="color:green">**L3: Display LinkedList**</span>
# Display all elements in a linked list (1 -> 2 -> 3 -> None).
#
# **Expected Output:**
# ```
# 1 -> 2 -> 3 -> None
# ```

# %%
# L3 Solution

# %% [markdown]
# <span style="color:green">**L4: Insert at Beginning**</span>
# Insert a new node at the beginning of linked list.
#
# **Expected Output:**
# ```
# 5 -> 3 -> 2 -> None
# ```

# %%
# L4 Solution

# %% [markdown]
# <span style="color:green">**L5: Insert at End**</span>
# Insert a new node at the end of linked list.
#
# **Expected Output:**
# ```
# 1 -> 2 -> 3 -> 5 -> None
# ```

# %%
# L5 Solution

# %% [markdown]
# ---
#
# ## INTERMEDIATE (Problems 6-12)

# %% [markdown]
# <span style="color:green">**L6: Insert at Position**</span>
# Insert node at specific position (e.g., at index 2).
#
# **Expected Output:**
# ```
# 1 -> 2 -> 5 -> 3 -> None
# ```

# %%
# L6 Solution

# %% [markdown]
# <span style="color:green">**L7: Delete Node by Value**</span>
# Delete first node with specific value from linked list.
#
# **Expected Output:**
# ```
# 1 -> 3 -> None
# ```

# %%
# L7 Solution

# %% [markdown]
# <span style="color:green">**L8: Search for Value**</span>
# Search for a value in linked list and return position or -1.
#
# **Expected Output:**
# ```
# Value found at position 2
# ```

# %%
# L8 Solution

# %% [markdown]
# <span style="color:green">**L9: Get Length**</span>
# Calculate the length of linked list.
#
# **Expected Output:**
# ```
# 3
# ```

# %%
# L9 Solution

# %% [markdown]
# <span style="color:green">**L10: Reverse LinkedList**</span>
# Reverse the entire linked list (1 -> 2 -> 3 becomes 3 -> 2 -> 1).
#
# **Expected Output:**
# ```
# 3 -> 2 -> 1 -> None
# ```

# %%
# L10 Solution

# %% [markdown]
# <span style="color:green">**L11: Find Middle Element**</span>
# Find the middle element in a linked list using slow and fast pointers.
#
# **Expected Output:**
# ```
# Middle element: 3
# ```

# %%
# L11 Solution

# %% [markdown]
# <span style="color:green">**L12: Find Nth Node from End**</span>
# Find the Nth node from the end of linked list (e.g., 2nd from end).
#
# **Expected Output:**
# ```
# 2nd node from end: 2
# ```

# %%
# L12 Solution

# %% [markdown]
# ---
#
# ## ADVANCED (Problems 13-17)

# %% [markdown]
# <span style="color:green">**L13: Detect Cycle**</span>
# Detect if linked list has a cycle using Floyd's cycle detection algorithm.
#
# **Expected Output:**
# ```
# Cycle detected!
# ```

# %%
# L13 Solution

# %% [markdown]
# <span style="color:green">**L14: Merge Two Sorted LinkedLists**</span>
# Merge two sorted linked lists into one sorted linked list.
#
# **Expected Output:**
# ```
# 1 -> 1 -> 2 -> 3 -> 4 -> 5 -> None
# ```

# %%
# L14 Solution

# %% [markdown]
# <span style="color:green">**L15: Remove Duplicates**</span>
# Remove duplicate values from linked list while preserving order.
#
# **Expected Output:**
# ```
# 1 -> 2 -> 3 -> 4 -> None
# ```

# %%
# L15 Solution

# %% [markdown]
# <span style="color:green">**L16: Check if Palindrome**</span>
# Check if linked list values form a palindrome (1 -> 2 -> 2 -> 1).
#
# **Expected Output:**
# ```
# True (is palindrome)
# ```

# %%
# L16 Solution

# %% [markdown]
# <span style="color:green">**L17: Swap Adjacent Nodes**</span>
# Swap every pair of adjacent nodes (1 -> 2 -> 3 -> 4 becomes 2 -> 1 -> 4 -> 3).
#
# **Expected Output:**
# ```
# 2 -> 1 -> 4 -> 3 -> None
# ```

# %%
# L17 Solution

# %% [markdown]
# ---
#
# ## EXPERT (Problems 18-20)

# %% [markdown]
# <span style="color:green">**L18: Reverse Nodes in K-Group**</span>
# Reverse every K nodes in linked list (K=2: 1->2->3->4 becomes 2->1->4->3).
#
# **Expected Output:**
# ```
# 2 -> 1 -> 4 -> 3 -> None
# ```

# %%
# L18 Solution

# %% [markdown]
# <span style="color:green">**L19: Find Intersection Point of Two LinkedLists**</span>
# Find the node where two linked lists intersect. Both lists share common nodes from intersection point.
#
# **Expected Output:**
# ```
# Intersection at node with value: 4
# ```

# %%
# L19 Solution

# %% [markdown]
# <span style="color:green">**L20: Flatten Multilevel LinkedList**</span>
# Flatten a multilevel linked list where each node has a 'child' pointer in addition to 'next'.
#
# **Expected Output:**
# ```
# 1 -> 2 -> 3 -> 4 -> 5 -> 6 -> 7 -> None
# ```

# %%
# L20 Solution

# %% [markdown]
# ---
#
# ## Summary
#
# You've covered 20 linked list problems from basic to expert level!
#
# **Topics Covered:**
# - **L1-L5 (EASY):** Node/LinkedList creation, display, insert at beginning/end
# - **L6-L12 (INTERMEDIATE):** Insert at position, delete, search, length, reverse, middle, Nth from end
# - **L13-L17 (ADVANCED):** Cycle detection, merge, remove duplicates, palindrome, swap adjacent
# - **L18-L20 (EXPERT):** Reverse K-group, intersection point, flatten multilevel
#
# **Key Concepts:**
# - Pointer manipulation
# - Traversal and iteration
# - Two-pointer technique (slow/fast pointers)
# - Recursion in linked lists
# - Complex algorithms (cycle detection, merging, etc.)
