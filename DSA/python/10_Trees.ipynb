# %% [markdown]
# # Trees Assessment - 20 Problems
#
# Master trees: traversal, BST, paths, LCA, advanced patterns
#
# ---
#
# ## EASY (TR1-TR5)

# %% [markdown]
# <span style="color:green">**TR1: Inorder Traversal**</span>
# Inorder traverse tree [3,9,20,null,null,15,7].
#
# **Output:** `[9, 3, 15, 20, 7]`

# %%
# TR1 Solution

# %% [markdown]
# <span style="color:green">**TR2: Preorder Traversal**</span>
# Preorder traverse tree [3,9,20,null,null,15,7].
#
# **Output:** `[3, 9, 20, 15, 7]`

# %%
# TR2 Solution

# %% [markdown]
# <span style="color:green">**TR3: Postorder Traversal**</span>
# Postorder traverse tree [3,9,20,null,null,15,7].
#
# **Output:** `[9, 15, 7, 20, 3]`

# %%
# TR3 Solution

# %% [markdown]
# <span style="color:green">**TR4: Maximum Depth**</span>
# Find max depth [3,9,20,null,null,15,7].
#
# **Output:** `3`

# %%
# TR4 Solution

# %% [markdown]
# <span style="color:green">**TR5: Is Valid Binary Search Tree**</span>
# Validate BST [2,1,3].
#
# **Output:** `True`
