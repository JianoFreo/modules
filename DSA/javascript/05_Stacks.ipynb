# %% [markdown]
# # Stacks - 20 Problems
#
# Master stacks: LIFO operations, parsing, expression evaluation
#
# ---
#
# ## EASY (ST1-ST5)

# %% [markdown]
# <span style="color:green">**ST1: Basic Stack Operations**</span>
# Push, pop, peek operations.
#
# **Output:** Stack operations

# %% [markdown]
# <span style="color:green">**ST2: Valid Parentheses**</span>
# Check if '()[]{}' is valid.
#
# **Output:** `true`

# %% [markdown]
# <span style="color:green">**ST3: Reverse String**</span>
# Use stack to reverse 'hello'.
#
# **Output:** `'olleh'`

# %% [markdown]
# <span style="color:green">**ST4: Backspace String**</span>
# Process backspace in 'ab#c#d#'.
#
# **Output:** `'ad'`

# %% [markdown]
# <span style="color:green">**ST5: Min Stack**</span>
# Stack that supports O(1) getMin().
#
# **Output:** Min element at any time

# %% [markdown]
# ---
#
# ## INTERMEDIATE (ST6-ST12)

# %% [markdown]
# <span style="color:green">**ST6: Evaluate RPN**</span>
# Evaluate reverse polish notation: ['2', '1', '+', '3', '*'].
#
# **Output:** `9`

# %% [markdown]
# <span style="color:green">**ST7: Next Greater Element**</span>
# Find next greater for each in [1, 2, 1].
#
# **Output:** `[2, -1, -1]`

# %% [markdown]
# <span style="color:green">**ST8: Trapping Rain Water**</span>
# Calculate trapped water using stack.
#
# **Output:** Amount of water

# %% [markdown]
# <span style="color:green">**ST9: Largest Rectangle**</span>
# Largest rectangle in histogram.
#
# **Output:** Max area

# %% [markdown]
# <span style="color:green">**ST10: Decode String**</span>
# Decode '3[a2[c]]' to 'accaccacc'.
#
# **Output:** `'accaccacc'`

# %% [markdown]
# <span style="color:green">**ST11: Basic Calculator**</span>
# Evaluate math expression '1 + 1'.
#
# **Output:** Result

# %% [markdown]
# <span style="color:green">**ST12: Asteroid Collision**</span>
# Simulate asteroid collision [5, 10, -5].
#
# **Output:** `[5, 10]`

# %% [markdown]
# ---
#
# ## ADVANCED (ST13-ST17)

# %% [markdown]
# <span style="color:green">**ST13: Remove K Digits**</span>
# Remove k digits to get smallest number.
#
# **Output:** Smallest number string

# %% [markdown]
# <span style="color:green">**ST14: Max Stack**</span>
# Stack with O(1) push, pop, getMax, popMax.
#
# **Output:** All operations

# %% [markdown]
# <span style="color:green">**ST15: Online Stock Span**</span>
# Span of consecutive days with price <= today.
#
# **Output:** Span values

# %% [markdown]
# <span style="color:green">**ST16: Build Array by Rules**</span>
# Use stack to build array following rules.
#
# **Output:** Final array

# %% [markdown]
# <span style="color:green">**ST17: Verify Preorder**</span>
# Verify preorder sequence of BST.
#
# **Output:** `true` or `false`

# %% [markdown]
# ---
#
# ## EXPERT (ST18-ST20)

# %% [markdown]
# <span style="color:green">**ST18: Expression Evaluation**</span>
# Evaluate complex expression with functions.
#
# **Output:** Result

# %% [markdown]
# <span style="color:green">**ST19: Priority Queue**</span>
# Implement stack-based priority queue.
#
# **Output:** Priority operations

# %% [markdown]
# <span style="color:green">**ST20: Monotonic Stack Pattern**</span>
# Advanced monotonic stack patterns.
#
# **Output:** Pattern results

# %% [markdown]
# ---
#
# ## Summary
# Stacks mastery: basic operations → parsing → monotonic patterns → advanced algorithms
