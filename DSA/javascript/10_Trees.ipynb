# %% [markdown]
# # Trees - 20 Problems
#
# Master trees: traversal, BST, paths
#
# ---
#
# ## EASY (TR1-TR5)

# %% [markdown]
# <span style="color:green">**TR1: Inorder Traversal**</span>
#
# Return inorder traversal.

# %% [markdown]
# <span style="color:green">**TR2: Preorder Traversal**</span>
#
# Return preorder traversal.

# %% [markdown]
# <span style="color:green">**TR3: Postorder Traversal**</span>
#
# Return postorder traversal.

# %% [markdown]
# <span style="color:green">**TR4: Level Order Traversal**</span>
#
# Return level order.

# %% [markdown]
# <span style="color:green">**TR5: Maximum Depth**</span>
#
# Find max depth.

# %% [markdown]
# ---
#
# ## INTERMEDIATE (TR6-TR12)

# %% [markdown]
# <span style="color:green">**TR6: Validate BST**</span>
#
# Validate if tree is valid BST.

# %% [markdown]
# <span style="color:green">**TR7: Lowest Common Ancestor**</span>
#
# Find LCA.

# %% [markdown]
# <span style="color:green">**TR8: Path Sum**</span>
#
# Check if path exists with target sum.

# %% [markdown]
# <span style="color:green">**TR9: Symmetric Tree**</span>
#
# Check if tree is symmetric.

# %% [markdown]
# <span style="color:green">**TR10: Invert Binary Tree**</span>
#
# Invert tree.

# %% [markdown]
# <span style="color:green">**TR11: Diameter of Binary Tree**</span>
#
# Find diameter.

# %% [markdown]
# <span style="color:green">**TR12: Balanced Binary Tree**</span>
#
# Check if balanced.

# %% [markdown]
# ---
#
# ## ADVANCED (TR13-TR17)

# %% [markdown]
# <span style="color:green">**TR13: Serialize and Deserialize**</span>
#
# Serialize and deserialize tree.

# %% [markdown]
# <span style="color:green">**TR14: Binary Tree Maximum Path Sum**</span>
#
# Find max path sum.

# %% [markdown]
# <span style="color:green">**TR15: Construct Tree from Preorder and Inorder**</span>
#
# Build tree.

# %% [markdown]
# <span style="color:green">**TR16: Vertical Order Traversal**</span>
#
# Return vertical order.

# %% [markdown]
# <span style="color:green">**TR17: Binary Tree Right Side View**</span>
#
# Return right side view.

# %% [markdown]
# ---
#
# ## EXPERT (TR18-TR20)

# %% [markdown]
# <span style="color:green">**TR18: Recover BST**</span>
#
# Recover corrupted BST.

# %% [markdown]
# <span style="color:green">**TR19: All Paths Root to Leaf**</span>
#
# Find all paths.

# %% [markdown]
# <span style="color:green">**TR20: Smallest Subtree with All Deepest Nodes**</span>
#
# Find smallest subtree.

# %% [markdown]
# ---
#
# ## Summary
#
# Trees mastery
