# %% [markdown]
# # Greedy - 20 Problems
#
# Master greedy algorithms
#
# ---
#
# ## EASY (GR1-GR5)

# %% [markdown]
# <span style="color:green">**GR1: Best Time to Buy Stock**</span>
#
# Find max profit.
#
# **Input:** `[7,1,5,3,6,4]`
#
# **Expected Output:** `5`

# %% [markdown]
# <span style="color:green">**GR2: Assign Cookies**</span>
#
# Maximize satisfied children.
#
# **Input:** `g = [1,2,3], s = [1,1]`
#
# **Expected Output:** `1`

# %% [markdown]
# <span style="color:green">**GR3: Valid Parentheses String**</span>
#
# Check if valid.
#
# **Input:** `s = "()`
#
# **Expected Output:** `true`

# %% [markdown]
# <span style="color:green">**GR4: Jump Game**</span>
#
# Can reach last index?
#
# **Input:** `[2,3,1,1,4]`
#
# **Expected Output:** `true`

# %% [markdown]
# <span style="color:green">**GR5: Minimum Platforms**</span>
#
# Find platforms needed.
#
# **Input:** `arrival = [900,940,950], departure = [910,1200,1120]`
#
# **Expected Output:** `1`

# %% [markdown]
# ---
#
# ## INTERMEDIATE (GR6-GR12)

# %% [markdown]
# <span style="color:green">**GR6: Activity Selection**</span>
#
# Max non-overlapping activities.
#
# **Input:** `start = [1,3,0,5,8,5], end = [2,4,6,7,9,9]`
#
# **Expected Output:** `4`

# %% [markdown]
# <span style="color:green">**GR7: Fractional Knapsack**</span>
#
# Max value.
#
# **Input:** `items = [[60,10],[100,20],[120,30]], capacity = 50`
#
# **Expected Output:** `240.0`

# %% [markdown]
# <span style="color:green">**GR8: Jump Game II**</span>
#
# Minimum jumps.
#
# **Input:** `[2,3,1,1,4]`
#
# **Expected Output:** `2`

# %% [markdown]
# <span style="color:green">**GR9: Interval Merging**</span>
#
# Merge overlapping.
#
# **Input:** `[[1,3],[2,6],[8,10],[15,18]]`
#
# **Expected Output:** `[[1,6],[8,10],[15,18]]`

# %% [markdown]
# <span style="color:green">**GR10: Meeting Rooms**</span>
#
# Check if can attend.
#
# **Input:** `[[0,30],[5,10],[15,20]]`
#
# **Expected Output:** `false`

# %% [markdown]
# <span style="color:green">**GR11: Gas Station**</span>
#
# Start station.
#
# **Input:** `gas = [1,2,3,4,5], cost = [3,4,5,1,2]`
#
# **Expected Output:** `3`

# %% [markdown]
# <span style="color:green">**GR12: Candy Distribution**</span>
#
# Minimum candies.
#
# **Input:** `[1,0,2]`
#
# **Expected Output:** `5`

# %% [markdown]
# ---
#
# ## ADVANCED (GR13-GR17)

# %% [markdown]
# <span style="color:green">**GR13: Meeting Rooms II**</span>
#
# Minimum rooms.
#
# **Input:** `[[0,30],[5,10],[15,20]]`
#
# **Expected Output:** `2`

# %% [markdown]
# <span style="color:green">**GR14: Optimal Task Scheduling**</span>
#
# Schedule with idle time.
#
# **Input:** `["A","A","A","B","B","B"], n = 2`
#
# **Expected Output:** `8`

# %% [markdown]
# <span style="color:green">**GR15: Maximum Subarray**</span>
#
# Find max sum.
#
# **Input:** `[-2,1,-3,4,-1,2,1,-5,4]`
#
# **Expected Output:** `6`

# %% [markdown]
# <span style="color:green">**GR16: Rearrange String K Distance Apart**</span>
#
# Rearrange with k distance.
#
# **Input:** `s = "ababc", k = 3`
#
# **Expected Output:** `"abacb"`

# %% [markdown]
# <span style="color:green">**GR17: Largest Number**</span>
#
# Form largest.
#
# **Input:** `[3,30,34,5,9]`
#
# **Expected Output:** `"9534330"`

# %% [markdown]
# ---
#
# ## EXPERT (GR18-GR20)

# %% [markdown]
# <span style="color:green">**GR18: Wildcard Matching**</span>
#
# Match pattern.
#
# **Input:** `s = "aa", p = "a"`
#
# **Expected Output:** `false`

# %% [markdown]
# <span style="color:green">**GR19: Minimum Number of Arrows**</span>
#
# Burst balloons.
#
# **Input:** `[[10,16],[2,8],[1,6],[7,12]]`
#
# **Expected Output:** `2`
#
# Burst balloons.

# %% [markdown]
# <span style="color:green">**GR20: Reconstructing Course Schedule**</span>
#
# Schedule with prerequisites.
#
# **Input:** `numCourses = 2, prerequisites = [[1,0]]`
#
# **Expected Output:** `[0,1]`

# %% [markdown]
# ---
#
# ## Summary
#
# Greedy mastery
