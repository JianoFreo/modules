# %% [markdown]
# # Queues - 20 Problems
#
# Master queues: FIFO operations, sliding window, level-order traversal
#
# ---
#
# ## EASY (Q1-Q5)

# %% [markdown]
# <span style="color:green">**Q1: Basic Queue Operations**</span>
# Implement queue with enqueue, dequeue, peek.
#
# **Output:** Queue operations results

# %% [markdown]
# <span style="color:green">**Q2: Moving Average**</span>
# Calculate moving average of last k elements.
#
# **Output:** `[1.0, 1.5, 2.0, 2.5]`

# %% [markdown]
# <span style="color:green">**Q3: Sliding Window Maximum**</span>
# Find max in sliding window of size k.
#
# **Output:** `[3, 3, 5, 5]`

# %% [markdown]
# <span style="color:green">**Q4: First Unique Character**</span>
# Find first character that appears once.
#
# **Output:** `'b'`

# %% [markdown]
# <span style="color:green">**Q5: Circular Queue**</span>
# Implement circular queue of size k.
#
# **Output:** Circular queue operations

# %% [markdown]
# ---
#
# ## INTERMEDIATE (Q6-Q12)

# %% [markdown]
# <span style="color:green">**Q6: Level Order Traversal**</span>
# BFS traversal of binary tree.
#
# **Output:** `[[1], [2, 3], [4, 5]]`

# %% [markdown]
# <span style="color:green">**Q7: Number of Islands**</span>
# Count connected components using queue.
#
# **Output:** `3`

# %% [markdown]
# <span style="color:green">**Q8: Shortest Path**</span>
# Find shortest path in grid with obstacles.
#
# **Output:** Distance

# %% [markdown]
# <span style="color:green">**Q9: Perfect Squares**</span>
# Find minimum squares that sum to n.
#
# **Output:** `3` for n=7

# %% [markdown]
# <span style="color:green">**Q10: Wall and Gates**</span>
# Update distances to nearest gate.
#
# **Output:** Updated grid

# %% [markdown]
# <span style="color:green">**Q11: Ugly Numbers**</span>
# Find nth ugly number (2, 3, 5 factors).
#
# **Output:** `10`

# %% [markdown]
# <span style="color:green">**Q12: Stack Queues**</span>
# Implement queue using stacks.
#
# **Output:** Queue operations

# %% [markdown]
# ---
#
# ## ADVANCED (Q13-Q17)

# %% [markdown]
# <span style="color:green">**Q13: Trapping Rain Water II**</span>
# 3D version using priority queue.
#
# **Output:** Total water trapped

# %% [markdown]
# <span style="color:green">**Q14: Task Scheduler**</span>
# Schedule tasks with cooling period.
#
# **Output:** `8`

# %% [markdown]
# <span style="color:green">**Q15: Alien Dictionary**</span>
# Derive order using topological sort.
#
# **Output:** `'wertmn'`

# %% [markdown]
# <span style="color:green">**Q16: Binary Tree Zigzag**</span>
# Zigzag level order traversal.
#
# **Output:** `[[1], [3, 2], [4, 5]]`

# %% [markdown]
# <span style="color:green">**Q17: Min Stack Queue**</span>
# Queue with O(1) getMin.
#
# **Output:** Min at each step

# %% [markdown]
# ---
#
# ## EXPERT (Q18-Q20)

# %% [markdown]
# <span style="color:green">**Q18: Median Data Stream**</span>
# Find median using heaps and queues.
#
# **Output:** `2.5`

# %% [markdown]
# <span style="color:green">**Q19: Dijkstra Algorithm**</span>
# Shortest path using priority queue.
#
# **Output:** Distances

# %% [markdown]
# <span style="color:green">**Q20: LRU Cache Advanced**</span>
# LRU with ordering queue.
#
# **Output:** Cache operations

# %% [markdown]
# ---
#
# ## Summary
# Queues mastery: FIFO operations → level-order traversal → graph algorithms → advanced patterns
