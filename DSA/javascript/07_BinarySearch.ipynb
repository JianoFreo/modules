# %% [markdown]
# # Binary Search - 20 Problems
#
# Master binary search: classic search, rotated arrays, boundary conditions
#
# ---
#
# ## EASY (BS1-BS5)

# %% [markdown]
# <span style="color:green">**BS1: Classic Binary Search**</span>
# Find target in sorted array.
#
# **Output:** `3`

# %% [markdown]
# <span style="color:green">**BS2: First Bad Version**</span>
# Find first bad version number.
#
# **Output:** `4`

# %% [markdown]
# <span style="color:green">**BS3: Search Insert Position**</span>
# Find position to insert target.
#
# **Output:** `2`

# %% [markdown]
# <span style="color:green">**BS4: Sqrt(x)**</span>
# Find integer square root.
#
# **Output:** `2`

# %% [markdown]
# <span style="color:green">**BS5: Peak Element**</span>
# Find peak element (greater than neighbors).
#
# **Output:** `2`

# %% [markdown]
# ---
#
# ## INTERMEDIATE (BS6-BS12)

# %% [markdown]
# <span style="color:green">**BS6: Search Rotated Array**</span>
# Search in rotated sorted array.
#
# **Output:** `4`

# %% [markdown]
# <span style="color:green">**BS7: Minimum in Rotated**</span>
# Find minimum in rotated sorted array.
#
# **Output:** `1`

# %% [markdown]
# <span style="color:green">**BS8: Search Range**</span>
# Find first and last position of target.
#
# **Output:** `[3, 4]`

# %% [markdown]
# <span style="color:green">**BS9: Find K Closest**</span>
# Find k closest elements to target.
#
# **Output:** `[1, 2, 3]`

# %% [markdown]
# <span style="color:green">**BS10: Time Based KV**</span>
# Binary search on time dimension.
#
# **Output:** `'bar'`

# %% [markdown]
# <span style="color:green">**BS11: Find Duplicate**</span>
# Find duplicate number in array.
#
# **Output:** `2`

# %% [markdown]
# <span style="color:green">**BS12: Capacity Ship**</span>
# Find min ship capacity for days.
#
# **Output:** `15`

# %% [markdown]
# ---
#
# ## ADVANCED (BS13-BS17)

# %% [markdown]
# <span style="color:green">**BS13: Median Sorted Arrays**</span>
# Find median of two sorted arrays.
#
# **Output:** `2.5`

# %% [markdown]
# <span style="color:green">**BS14: Koko Eating Bananas**</span>
# Find min eating speed to finish bananas.
#
# **Output:** `4`

# %% [markdown]
# <span style="color:green">**BS15: Split Array Largest**</span>
# Find minimum largest sum of subarrays.
#
# **Output:** `18`

# %% [markdown]
# <span style="color:green">**BS16: Index K Distinct**</span>
# Find first index with k distinct characters.
#
# **Output:** `3`

# %% [markdown]
# <span style="color:green">**BS17: Find Peak 2D**</span>
# Find peak in 2D matrix.
#
# **Output:** `[1, 1]`

# %% [markdown]
# ---
#
# ## EXPERT (BS18-BS20)

# %% [markdown]
# <span style="color:green">**BS18: Smallest Range**</span>
# Find smallest range from k lists.
#
# **Output:** `[20, 24]`

# %% [markdown]
# <span style="color:green">**BS19: Random Pick Weight**</span>
# Random selection with weights.
#
# **Output:** Weighted random index

# %% [markdown]
# <span style="color:green">**BS20: Maximum Profit Stock**</span>
# Advanced stock trading binary search.
#
# **Output:** `4`

# %% [markdown]
# ---
#
# ## Summary
# Binary Search mastery: classic search → rotated arrays → boundary optimization → advanced patterns
