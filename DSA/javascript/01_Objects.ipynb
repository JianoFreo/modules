# %% [markdown]
# # JavaScript Objects - 20 Problems
#
# Master objects: creation, access, manipulation, nesting, and advanced operations
#
# ---
#
# ## EASY (J1-J5)

# %% [markdown]
# <span style="color:green">**J1: Create and Access Object**</span>
# Create an object with person info and access properties.
#
# **Output:** `Alice, 25, Engineer`

# %%
// J1 Solution

# %% [markdown]
# <span style="color:green">**J2: Check if Property Exists**</span>
# Use hasOwnProperty() and in operator to check properties.
#
# **Output:** `true, false, true`

# %%
// J2 Solution

# %% [markdown]
# <span style="color:green">**J3: Add and Modify Properties**</span>
# Add new properties and modify existing ones.
#
# **Output:** `{ name: 'Alice', age: 26, email: 'alice@example.com' }`

# %%
// J3 Solution

# %% [markdown]
# <span style="color:green">**J4: Delete Object Properties**</span>
# Remove properties using delete operator.
#
# **Output:** `{ name: 'Alice' }`

# %%
// J4 Solution

# %% [markdown]
# <span style="color:green">**J5: Iterate Through Object Properties**</span>
# Loop through keys, values, and entries.
#
# **Output:** All keys, values, and key-value pairs

# %%
// J5 Solution

# %% [markdown]
# ---
#
# ## INTERMEDIATE (J6-J12)

# %% [markdown]
# <span style="color:green">**J6: Object Spread and Merge**</span>
# Merge two objects using spread operator.
#
# **Output:** `{ a: 1, b: 2, c: 3, d: 4 }`

# %%
// J6 Solution

# %% [markdown]
# <span style="color:green">**J7: Convert Object to Array**</span>
# Convert object to array of keys, values, or entries.
#
# **Output:** `[ 'name', 'age', 'city' ]` or `[ [ 'name', 'John' ], [ 'age', 30 ] ]`

# %%
// J7 Solution

# %% [markdown]
# <span style="color:green">**J8: Count Occurrences**</span>
# Count how many times each element appears in an array using an object.
#
# **Output:** `{ apple: 3, banana: 2, orange: 1 }`

# %%
// J8 Solution

# %% [markdown]
# <span style="color:green">**J9: Transform Object Values**</span>
# Transform all values in an object (multiply by 2, add prefix, etc).
#
# **Output:** `{ a: 2, b: 4, c: 6 }`

# %%
// J9 Solution

# %% [markdown]
# <span style="color:green">**J10: Filter Object by Values**</span>
# Keep only properties with values greater than 5.
#
# **Output:** `{ b: 10, c: 8 }`

# %%
// J10 Solution

# %% [markdown]
# <span style="color:green">**J11: Find Key by Value**</span>
# Find the key that has a specific value.
#
# **Output:** `name` (key for value 'John')

# %%
// J11 Solution

# %% [markdown]
# <span style="color:green">**J12: Deep Freeze Object**</span>
# Make an object immutable using Object.freeze().
#
# **Output:** Show that properties cannot be modified

# %%
// J12 Solution

# %% [markdown]
# ---
#
# ## ADVANCED (J13-J17)

# %% [markdown]
# <span style="color:green">**J13: Nested Object Access with Defaults**</span>
# Access deeply nested properties safely with optional chaining.
#
# **Output:** `undefined or default value`

# %%
// J13 Solution

# %% [markdown]
# <span style="color:green">**J14: Clone vs Reference**</span>
# Understand shallow copy vs deep copy of objects.
#
# **Output:** Show how nested objects are affected differently

# %%
// J14 Solution

# %% [markdown]
# <span style="color:green">**J15: Group Array by Property**</span>
# Group objects in an array by a specific property.
#
# **Output:** Grouped by category or type

# %%
// J15 Solution

# %% [markdown]
# <span style="color:green">**J16: Destructuring Assignment**</span>
# Extract values from objects using destructuring.
#
# **Output:** `Alice, 25, Engineer`

# %%
// J16 Solution

# %% [markdown]
# <span style="color:green">**J17: Flatten Nested Object**</span>
# Flatten a multi-level nested object into a single level with dot notation keys.
#
# **Output:** `{ 'user.name': 'John', 'user.address.city': 'NYC' }`

# %%
// J17 Solution

# %% [markdown]
# ---
#
# ## EXPERT (J18-J20)

# %% [markdown]
# <span style="color:green">**J18: Proxy Objects**</span>
# Create a Proxy to intercept and validate object operations.
#
# **Output:** Log all property accesses and modifications

# %%
// J18 Solution

# %% [markdown]
# <span style="color:green">**J19: Map vs Object Performance**</span>
# Compare using Map vs regular objects for key-value storage.
#
# **Output:** Performance comparison and use cases

# %%
// J19 Solution

# %% [markdown]
# <span style="color:green">**J20: WeakMap for Private Data**</span>
# Use WeakMap to store private object data.
#
# **Output:** Demonstrate encapsulation with WeakMap

# %%
// J20 Solution

# %% [markdown]
# ---
#
# ## Summary
# JavaScript Objects mastery: creation → access → manipulation → nesting → advanced patterns with Proxy, Map, and WeakMap
