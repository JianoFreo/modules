# %% [markdown]
# # Graphs - 20 Problems
#
# Master graphs: BFS, DFS, paths
#
# ---
#
# ## EASY (GP1-GP5)

# %% [markdown]
# <span style="color:green">**GP1: DFS Traversal**</span>
#
# Return DFS.

# %% [markdown]
# <span style="color:green">**GP2: BFS Traversal**</span>
#
# Return BFS.

# %% [markdown]
# <span style="color:green">**GP3: Number of Islands**</span>
#
# Count islands.

# %% [markdown]
# <span style="color:green">**GP4: Detect Cycle**</span>
#
# Detect cycle.

# %% [markdown]
# <span style="color:green">**GP5: Connected Components**</span>
#
# Count components.

# %% [markdown]
# ---
#
# ## INTERMEDIATE (GP6-GP12)

# %% [markdown]
# <span style="color:green">**GP6: Shortest Path BFS**</span>
#
# Find shortest path.

# %% [markdown]
# <span style="color:green">**GP7: Course Schedule**</span>
#
# Complete courses.

# %% [markdown]
# <span style="color:green">**GP8: Topological Sort**</span>
#
# Sort topologically.

# %% [markdown]
# <span style="color:green">**GP9: Bipartite Graph**</span>
#
# Check if bipartite.

# %% [markdown]
# <span style="color:green">**GP10: Flood Fill**</span>
#
# Fill color.

# %% [markdown]
# <span style="color:green">**GP11: Strongly Connected Components**</span>
#
# Find SCCs.

# %% [markdown]
# <span style="color:green">**GP12: All Paths Source to Target**</span>
#
# Find paths.

# %% [markdown]
# ---
#
# ## ADVANCED (GP13-GP17)

# %% [markdown]
# <span style="color:green">**GP13: Dijkstra's Algorithm**</span>
#
# Find shortest path.

# %% [markdown]
# <span style="color:green">**GP14: Network Flow**</span>
#
# Maximum flow.

# %% [markdown]
# <span style="color:green">**GP15: Critical Connection**</span>
#
# Find bridges.

# %% [markdown]
# <span style="color:green">**GP16: Wall and Gates**</span>
#
# Distance to gate.

# %% [markdown]
# <span style="color:green">**GP17: Alien Dictionary**</span>
#
# Order characters.

# %% [markdown]
# ---
#
# ## EXPERT (GP18-GP20)

# %% [markdown]
# <span style="color:green">**GP18: Minimum Spanning Tree**</span>
#
# Find MST.

# %% [markdown]
# <span style="color:green">**GP19: Bellman Ford**</span>
#
# Shortest path with negative edges.

# %% [markdown]
# <span style="color:green">**GP20: Floyd Warshall**</span>
#
# All pairs shortest paths.

# %% [markdown]
# ---
#
# ## Summary
#
# Graphs mastery
