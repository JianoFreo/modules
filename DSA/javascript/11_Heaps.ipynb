# %% [markdown]
# # Heaps - 20 Problems
#
# Master heaps: priority queues
#
# ---
#
# ## EASY (HP1-HP5)

# %% [markdown]
# <span style="color:green">**HP1: Last Stone Weight**</span>
#
# Process stones.

# %% [markdown]
# <span style="color:green">**HP2: Kth Largest Element**</span>
#
# Find kth largest.

# %% [markdown]
# <span style="color:green">**HP3: Merge k Sorted Lists**</span>
#
# Merge k sorted lists.

# %% [markdown]
# <span style="color:green">**HP4: Top K Frequent Elements**</span>
#
# Find top k frequent.

# %% [markdown]
# <span style="color:green">**HP5: Min Cost to Connect Sticks**</span>
#
# Find min cost.

# %% [markdown]
# ---
#
# ## INTERMEDIATE (HP6-HP12)

# %% [markdown]
# <span style="color:green">**HP6: Kth Smallest Element**</span>
#
# Find kth smallest.

# %% [markdown]
# <span style="color:green">**HP7: Sliding Window Maximum**</span>
#
# Find max in each window.

# %% [markdown]
# <span style="color:green">**HP8: IPO**</span>
#
# Maximize capital.

# %% [markdown]
# <span style="color:green">**HP9: Reorganize String**</span>
#
# Reorganize with no adjacent duplicates.

# %% [markdown]
# <span style="color:green">**HP10: Find Median Data Stream**</span>
#
# Find median dynamically.

# %% [markdown]
# <span style="color:green">**HP11: Task Scheduler**</span>
#
# Schedule tasks.

# %% [markdown]
# <span style="color:green">**HP12: Furthest Building**</span>
#
# Reach furthest building.

# %% [markdown]
# ---
#
# ## ADVANCED (HP13-HP17)

# %% [markdown]
# <span style="color:green">**HP13: Smallest Range Covering Elements**</span>
#
# Find smallest range.

# %% [markdown]
# <span style="color:green">**HP14: Minimum Cost to Hire K Workers**</span>
#
# Find min cost.

# %% [markdown]
# <span style="color:green">**HP15: Network Delay Time**</span>
#
# Find delay.

# %% [markdown]
# <span style="color:green">**HP16: Maximum Performance**</span>
#
# Maximize performance.

# %% [markdown]
# <span style="color:green">**HP17: Assign Cookies**</span>
#
# Maximize satisfied children.

# %% [markdown]
# ---
#
# ## EXPERT (HP18-HP20)

# %% [markdown]
# <span style="color:green">**HP18: Trapping Rain Water II**</span>
#
# Calculate trapped water in 2D.

# %% [markdown]
# <span style="color:green">**HP19: Super Ugly Number**</span>
#
# Find kth super ugly.

# %% [markdown]
# <span style="color:green">**HP20: Median of Sorted Arrays Stream**</span>
#
# Find running median.

# %% [markdown]
# ---
#
# ## Summary
#
# Heaps mastery
