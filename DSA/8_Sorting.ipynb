# %% [markdown]
# # Sorting Assessment - 20 Problems
#
# Master sorting: classics, custom sorts, partial sorts, advanced algorithms
#
# ---
#
# ## EASY (SO1-SO5)

# %% [markdown]
# <span style="color:green">**SO1: Bubble Sort**</span>
# Implement bubble sort. [3,1,4,1,5].
#
# **Output:** `[1, 1, 3, 4, 5]`

# %%
# SO1 Solution

# %% [markdown]
# <span style="color:green">**SO2: Insertion Sort**</span>
# Implement insertion sort. [3,1,4,1,5].
#
# **Output:** `[1, 1, 3, 4, 5]`

# %%
# SO2 Solution

# %% [markdown]
# <span style="color:green">**SO3: Selection Sort**</span>
# Implement selection sort. [3,1,4,1,5].
#
# **Output:** `[1, 1, 3, 4, 5]`

# %%
# SO3 Solution

# %% [markdown]
# <span style="color:green">**SO4: Merge Sort**</span>
# Implement merge sort (divide & conquer). [3,1,4,1,5].
#
# **Output:** `[1, 1, 3, 4, 5]`

# %%
# SO4 Solution

# %% [markdown]
# <span style="color:green">**SO5: Quick Sort**</span>
# Implement quick sort (partition). [3,1,4,1,5].
#
# **Output:** `[1, 1, 3, 4, 5]`

# %%
# SO5 Solution

# %% [markdown]
# ---
#
# ## INTERMEDIATE (SO6-SO12)

# %% [markdown]
# <span style="color:green">**SO6: Heap Sort**</span>
# Implement heap sort. [3,1,4,1,5].
#
# **Output:** `[1, 1, 3, 4, 5]`

# %%
# SO6 Solution

# %% [markdown]
# <span style="color:green">**SO7: Custom Sort**</span>
# Sort by second element. [(1,2), (3,1), (2,2)].
#
# **Output:** `[(3, 1), (1, 2), (2, 2)]`

# %%
# SO7 Solution

# %% [markdown]
# <span style="color:green">**SO8: Largest Number**</span>
# Form largest number from [3,30,34,5,9].
#
# **Output:** `"9534330"`

# %%
# SO8 Solution

# %% [markdown]
# <span style="color:green">**SO9: Merge Sorted Arrays**</span>
# Merge [1,3] and [2].
#
# **Output:** `[1, 2, 3]`

# %%
# SO9 Solution

# %% [markdown]
# <span style="color:green">**SO10: Kth Largest Element**</span>
# Find 2nd largest in [3,2,1,5,6,4].
#
# **Output:** `5`

# %%
# SO10 Solution

# %% [markdown]
# <span style="color:green">**SO11: Top K Frequent Elements**</span>
# Find top 2 in [1,1,1,2,2,3], k=2.
#
# **Output:** `[1, 2]`

# %%
# SO11 Solution

# %% [markdown]
# <span style="color:green">**SO12: Relative Sort Array**</span>
# Sort arr1=[2,3,1,16,4,10] by arr2=[2,1,4,3,9].
#
# **Output:** `[2, 1, 4, 3, 16, 10]`

# %%
# SO12 Solution

# %% [markdown]
# ---
#
# ## ADVANCED (SO13-SO17)

# %% [markdown]
# <span style="color:green">**SO13: Counting Sort**</span>
# Sort with count method. [4,2,2,8,3,3,1].
#
# **Output:** `[1, 2, 2, 3, 3, 4, 8]`

# %%
# SO13 Solution

# %% [markdown]
# <span style="color:green">**SO14: Sort Colors**</span>
# Sort 0s, 1s, 2s in-place. [2,0,2,1,1,0].
#
# **Output:** `[0, 0, 1, 1, 2, 2]`

# %%
# SO14 Solution

# %% [markdown]
# <span style="color:green">**SO15: Wiggle Sort**</span>
# Sort so nums[i] < nums[i+1] > nums[i+2]. [3,5,2,1,6,4].
#
# **Output:** `[3, 5, 2, 6, 1, 4]` (one valid answer)

# %%
# SO15 Solution

# %% [markdown]
# <span style="color:green">**SO16: Sort Array By Parity**</span>
# Even numbers first. [3,1,2,4].
#
# **Output:** `[2, 4, 3, 1]` or `[4, 2, 1, 3]`

# %%
# SO16 Solution

# %% [markdown]
# <span style="color:green">**SO17: Meeting Rooms II**</span>
# Minimum conference rooms. [[0,30],[5,10],[15,20]].
#
# **Output:** `2` (overlapping rooms needed)

# %%
# SO17 Solution

# %% [markdown]
# ---
#
# ## EXPERT (SO18-SO20)

# %% [markdown]
# <span style="color:green">**SO18: Radix Sort**</span>
# Implement radix sort (digit-by-digit). [170,45,75,90,2,2,19].
#
# **Output:** `[2, 2, 19, 45, 75, 90, 170]`

# %%
# SO18 Solution

# %% [markdown]
# <span style="color:green">**SO19: Alien Dictionary**</span>
# Topological sort to determine character order from alien dictionary.
#
# **Output:** Valid character order

# %%
# SO19 Solution

# %% [markdown]
# <span style="color:green">**SO20: Minimum Swaps To Sort**</span>
# Minimum swaps to sort array. [2,8,5,4,1,3,6,7].
#
# **Output:** `3` swaps

# %%
# SO20 Solution

# %% [markdown]
# ---
#
# ## Summary
# Sorting mastery: classics → custom sorts → advanced algorithms
