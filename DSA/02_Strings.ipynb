# %% [markdown]
# # Strings Assessment - 20 Problems
#
# Master strings: frequency counting, palindrome, anagram, substring problems
#
# ---
#
# ## EASY (S1-S5)

# %% [markdown]
# <span style="color:green">**S1: Reverse String**</span>
# Reverse "hello".
#
# **Output:** `"olleh"`

# %%
word = "hello"
print(word[::-1])
# Out:
# olleh

# %% [markdown]
# <span style="color:green">**S2: Is Palindrome**</span>
# Check if "racecar" is palindrome.
#
# **Output:** `True`

# %%
word = "racecar"
if word[::-1] == word:
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# <span style="color:green">**S3: Character Frequency**</span>
# Count frequency of each character in "aabbcc".
#
# **Output:** `{'a': 2, 'b': 2, 'c': 2}`

# %%
# S3 Solution

# %% [markdown]
# <span style="color:green">**S4: Is Anagram**</span>
# Check if "listen" and "silent" are anagrams.
#
# **Output:** `True`

# %%
# S4 Solution

# %% [markdown]
# <span style="color:green">**S5: First Unique Character**</span>
# Find first non-repeating character in "loveleetcode".
#
# **Output:** `'v'`

# %%
# S5 Solution

# %% [markdown]
# ---
#
# ## INTERMEDIATE (S6-S12)

# %% [markdown]
# <span style="color:green">**S6: Valid Parentheses**</span>
# Check if "(){}[]" is valid.
#
# **Output:** `True`

# %%
# S6 Solution

# %% [markdown]
# <span style="color:green">**S7: Valid Palindrome (alphanumeric)**</span>
# Check if "A man, a plan, a canal: Panama" is palindrome (ignore spaces/punctuation).
#
# **Output:** `True`

# %%
# S7 Solution

# %% [markdown]
# <span style="color:green">**S8: Longest Common Prefix**</span>
# Find LCP in ["flower", "flow", "flight"].
#
# **Output:** `"fl"`

# %%
# S8 Solution

# %% [markdown]
# <span style="color:green">**S9: Longest Substring Without Repeating Characters**</span>
# Find longest in "abcabcbb".
#
# **Output:** `3` ("abc")

# %%
# S9 Solution

# %% [markdown]
# <span style="color:green">**S10: Isomorphic Strings**</span>
# Check if "egg" and "add" are isomorphic.
#
# **Output:** `True`

# %%
# S10 Solution

# %% [markdown]
# <span style="color:green">**S11: Group Anagrams**</span>
# Group ["eat", "tea", "ate", "dog", "god"].
#
# **Output:** `[["eat", "tea", "ate"], ["dog", "god"]]`

# %%
# S11 Solution

# %% [markdown]
# <span style="color:green">**S12: Word Pattern**</span>
# Check if pattern "abba" matches "dog dog cat cat".
#
# **Output:** `True`

# %%
# S12 Solution

# %% [markdown]
# ---
#
# ## ADVANCED (S13-S17)

# %% [markdown]
# <span style="color:green">**S13: Longest Palindromic Substring**</span>
# Find longest palindrome in "babad".
#
# **Output:** `"bab"` or `"aba"`

# %%
# S13 Solution

# %% [markdown]
# <span style="color:green">**S14: Minimum Window Substring**</span>
# Find minimum window with all chars. s="ADOBECODEBANC", t="ABC".
#
# **Output:** `"BANC"`

# %%
# S14 Solution

# %% [markdown]
# <span style="color:green">**S15: Regular Expression Matching**</span>
# Match "aa" with pattern "a" (support . and *).
#
# **Output:** `False`

# %%
# S15 Solution

# %% [markdown]
# <span style="color:green">**S16: String Compression**</span>
# Compress "aabbbcc" to "a2b3c2".
#
# **Output:** `"a2b3c2"`

# %%
# S16 Solution

# %% [markdown]
# <span style="color:green">**S17: Edit Distance**</span>
# Find minimum edits from "horse" to "ros".
#
# **Output:** `3`

# %%
# S17 Solution

# %% [markdown]
# ---
#
# ## EXPERT (S18-S20)

# %% [markdown]
# <span style="color:green">**S18: Wildcard Matching**</span>
# Match "aa" with pattern "*" (support ? and *).
#
# **Output:** `True`

# %%
# S18 Solution

# %% [markdown]
# <span style="color:green">**S19: Scramble String**</span>
# Check if s2 is scramble of s1. s1="great", s2="rgeat".
#
# **Output:** `True`

# %%
# S19 Solution

# %% [markdown]
# <span style="color:green">**S20: Shortest Palindrome**</span>
# Add minimum chars to make "race" palindrome.
#
# **Output:** `"ecarace"`

# %%
# S20 Solution

# %% [markdown]
# ---
#
# ## Summary
# Strings mastery: basic operations → frequency counting → palindrome → advanced DP
