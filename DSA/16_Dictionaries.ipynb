# %% [markdown]
# # Dictionaries Assessment - 20 Problems
#
# Master dictionaries: creation, access, manipulation, nesting, and advanced operations
#
# ---
#
# ## EASY (D1-D5)

# %% [markdown]
# <span style="color:green">**D1: Create and Access Dictionary**</span>
# Create a dictionary with student info and access values.
#
# **Output:** `John, 20, Computer Science`

# %%
# D1 Solution

# %% [markdown]
# <span style="color:green">**D2: Get Dictionary Values Safely**</span>
# Use get() method to access values with default fallback.
#
# **Output:** `John, Not Found`

# %%
# D2 Solution

# %% [markdown]
# <span style="color:green">**D3: Add and Update Dictionary Items**</span>
# Add new keys and update existing ones.
#
# **Output:** `{'name': 'John', 'age': 21, 'email': 'john@example.com'}`

# %%
# D3 Solution

# %% [markdown]
# <span style="color:green">**D4: Remove Dictionary Items**</span>
# Remove items using del and pop().
#
# **Output:** `Removed: john@example.com, Remaining: {'name': 'John'}`

# %%
# D4 Solution

# %% [markdown]
# <span style="color:green">**D5: Iterate Through Dictionary**</span>
# Iterate through keys, values, and items.
#
# **Output:** All keys, values, and key-value pairs

# %%
# D5 Solution

# %% [markdown]
# ---
#
# ## INTERMEDIATE (D6-D12)

# %% [markdown]
# <span style="color:green">**D6: Count Word Frequency**</span>
# Count frequency of words in a list.
#
# **Output:** `{'apple': 3, 'banana': 2, 'orange': 1}`

# %%
# D6 Solution

# %% [markdown]
# <span style="color:green">**D7: Merge Two Dictionaries**</span>
# Merge dict1 and dict2.
#
# **Output:** `{'a': 1, 'b': 2, 'c': 3, 'd': 4}`

# %%
# D7 Solution

# %% [markdown]
# <span style="color:green">**D8: Find Common Keys**</span>
# Find keys that exist in both dictionaries.
#
# **Output:** `{'b', 'c'}`

# %%
# D8 Solution

# %% [markdown]
# <span style="color:green">**D9: Invert Dictionary**</span>
# Swap keys and values.
#
# **Output:** `{1: 'a', 2: 'b', 3: 'c'}`

# %%
# D9 Solution

# %% [markdown]
# <span style="color:green">**D10: Filter Dictionary by Value**</span>
# Filter items where value > 2.
#
# **Output:** `{'b': 3, 'c': 5}`

# %%
# D10 Solution

# %% [markdown]
# <span style="color:green">**D11: Sort Dictionary by Values**</span>
# Sort dictionary by values in descending order.
#
# **Output:** `{'c': 5, 'b': 3, 'd': 2, 'a': 1}`

# %%
# D11 Solution

# %% [markdown]
# <span style="color:green">**D12: Group by Category**</span>
# Group items by category.
#
# **Output:** `{'fruit': ['apple', 'banana'], 'vegetable': ['carrot', 'broccoli']}`

# %%
# D12 Solution

# %% [markdown]
# ---
#
# ## ADVANCED (D13-D17)

# %% [markdown]
# <span style="color:green">**D13: Nested Dictionary Access**</span>
# Access and modify nested dictionaries.
#
# **Output:** `John, john@example.com, updated`

# %%
# D13 Solution

# %% [markdown]
# <span style="color:green">**D14: Deep Copy vs Shallow Copy**</span>
# Understand the difference between deep and shallow copy.
#
# **Output:** Show how nested changes affect shallow vs deep copies

# %%
# D14 Solution

# %% [markdown]
# <span style="color:green">**D15: Convert List of Tuples to Dictionary**</span>
# Convert [(1, 'a'), (2, 'b'), (3, 'c')] to dictionary.
#
# **Output:** `{1: 'a', 2: 'b', 3: 'c'}`

# %%
# D15 Solution

# %% [markdown]
# <span style="color:green">**D16: Find Duplicate Values in Dictionary**</span>
# Find keys with the same values.
#
# **Output:** `Values with duplicates and their keys`

# %%
# D16 Solution

# %% [markdown]
# <span style="color:green">**D17: Multi-level Nested Dictionary Flattening**</span>
# Flatten a nested dictionary structure.
#
# **Output:** Flattened key-value pairs

# %%
# D17 Solution

# %% [markdown]
# ---
#
# ## EXPERT (D18-D20)

# %% [markdown]
# <span style="color:green">**D18: defaultdict vs Regular Dictionary**</span>
# Use defaultdict to handle missing keys automatically.
#
# **Output:** Demonstrate default value behavior

# %%
# D18 Solution

# %% [markdown]
# <span style="color:green">**D19: OrderedDict and Insertion Order**</span>
# Work with OrderedDict and understand insertion order.
#
# **Output:** Demonstrate ordered vs regular dictionaries

# %%
# D19 Solution

# %% [markdown]
# <span style="color:green">**D20: Counter Class for Frequency Analysis**</span>
# Use Counter for advanced frequency counting and operations.
#
# **Output:** Most common elements and their frequencies

# %%
# D20 Solution

# %% [markdown]
# ---
#
# ## Summary
# Dictionaries mastery: creation → access → manipulation → nesting → advanced operations with special dict types
