# %% [markdown]
# # Binary Search Assessment - 20 Problems
#
# Master binary search: classic, variants, answer-based, boundaries
#
# ---
#
# ## EASY (BS1-BS5)

# %% [markdown]
# <span style="color:green">**BS1: Binary Search**</span>
# Find target 9 in [3,4,6,9,11,13,15] or return -1.
#
# **Output:** `3` (index)

# %%
# BS1 Solution

# %% [markdown]
# <span style="color:green">**BS2: First Bad Version**</span>
# Find first bad version (versions after bad are also bad).
#
# **Output:** First bad version index

# %%
# BS2 Solution

# %% [markdown]
# <span style="color:green">**BS3: Square Root**</span>
# Find integer square root of 8.
#
# **Output:** `2` (since 2*2 = 4 and 3*3 = 9)

# %%
# BS3 Solution

# %% [markdown]
# <span style="color:green">**BS4: Valid Perfect Square**</span>
# Check if 16 is perfect square.
#
# **Output:** `True`

# %%
# BS4 Solution

# %% [markdown]
# <span style="color:green">**BS5: Mountain Peak**</span>
# Find peak in [1,3,4,5,3,2] (increase then decrease).
#
# **Output:** `4` (max element index)

# %%
# BS5 Solution

# %% [markdown]
# ---
#
# ## INTERMEDIATE (BS6-BS12)

# %% [markdown]
# <span style="color:green">**BS6: Search in Rotated Sorted Array**</span>
# Find 3 in [4,5,6,7,0,1,2].
#
# **Output:** `-1` (not found)

# %%
# BS6 Solution

# %% [markdown]
# <span style="color:green">**BS7: Find First and Last Position**</span>
# Find range of 8 in [5,7,7,8,8,10].
#
# **Output:** `[3, 4]`

# %%
# BS7 Solution

# %% [markdown]
# <span style="color:green">**BS8: Search Insert Position**</span>
# Insert 5 into [1,3,5,6] (find insert position).
#
# **Output:** `2`

# %%
# BS8 Solution

# %% [markdown]
# <span style="color:green">**BS9: Guess Number Higher or Lower**</span>
# Find secret number with guess() function (binary search game).
#
# **Output:** The secret number

# %%
# BS9 Solution

# %% [markdown]
# <span style="color:green">**BS10: Find K Closest Elements**</span>
# Find 4 closest to 3 in [1,2,3,4,5].
#
# **Output:** `[1,2,3,4]`

# %%
# BS10 Solution

# %% [markdown]
# <span style="color:green">**BS11: Find Minimum in Rotated Array**</span>
# Find min in [3,4,5,1,2].
#
# **Output:** `1`

# %%
# BS11 Solution

# %% [markdown]
# <span style="color:green">**BS12: Single Element in Sorted Array**</span>
# Find single non-duplicate in [1,1,2,3,3,4,4,8,8].
#
# **Output:** `2`

# %%
# BS12 Solution

# %% [markdown]
# ---
#
# ## ADVANCED (BS13-BS17)

# %% [markdown]
# <span style="color:green">**BS13: Capacity To Ship Packages**</span>
# Min capacity for shipping. weights=[1,2,3,4,5], days=5.
#
# **Output:** `5` (ship 1 package per day)

# %%
# BS13 Solution

# %% [markdown]
# <span style="color:green">**BS14: Minimum Time to Complete All Tasks**</span>
# Min time with constraint (binary search answer).
#
# **Output:** Minimum time needed

# %%
# BS14 Solution

# %% [markdown]
# <span style="color:green">**BS15: Magnetic Force Between Two Balls**</span>
# Max min distance placing 3 balls in [1,2,8,9].
#
# **Output:** `3` (best is 1,2,8 or 1,9 can't work)

# %%
# BS15 Solution

# %% [markdown]
# <span style="color:green">**BS16: Koko Eating Bananas**</span>
# Min speed to eat all piles in h hours. piles=[1,1,1,1], h=4.
#
# **Output:** `1` (eat 1 per hour)

# %%
# BS16 Solution

# %% [markdown]
# <span style="color:green">**BS17: Allocate Mailboxes**</span>
# Minimize max distance to mailboxes (binary search + DP).
#
# **Output:** Minimum maximum distance

# %%
# BS17 Solution

# %% [markdown]
# ---
#
# ## EXPERT (BS18-BS20)

# %% [markdown]
# <span style="color:green">**BS18: Cherry Pickup II**</span>
# Maximum cherries collected (binary search + DP).
#
# **Output:** Maximum number of cherries

# %%
# BS18 Solution

# %% [markdown]
# <span style="color:green">**BS19: Maximum Number of Removals**</span>
# Max removals with constraints (binary search variant).
#
# **Output:** Maximum number of removals

# %%
# BS19 Solution

# %% [markdown]
# <span style="color:green">**BS20: Smallest Good Base**</span>
# Find smallest base for n (binary search answer).
#
# **Output:** Base as string

# %%
# BS20 Solution

# %% [markdown]
# ---
#
# ## Summary
# Binary search mastery: classic search → answer binary search → advanced variants
