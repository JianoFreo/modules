# %% [markdown]
# # STANDARD VARIATION

# %%
import numpy as np
x = [17, 18, 19, 2.5]
y = [20, 20, 20, 20]
#STD is a measure of the amount of varaition/dispersion

print(np.std(x))
# Out:
# 6.748842493346544

# %%
import numpy as np
x = [17, 18, 19, 2.5]
y = [20, 20, 20, 20]
#STD is a measure of the amount of varaition/dispersion

print(np.std(y))
# Out:
# 0.0

# %%
import numpy as np
x = [17, 18, 19, 2.5]
y = [20, 20, 20, 20]
#STD is a measure of the amount of varaition/dispersion

print(np.std(x, ddof=1)) # sample deviation
print(np.std(x, ddof=0)) # population deviation
# Out:
# 7.792892060504025

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)
# ![image-4.png](attachment:image-4.png)
